# %% [markdown]
# # Parameter Estimation for the HBV Infection Model Using DINNs
#
# This notebook applies **Disease-Informed Neural Networks (DINNs)** to estimate the unknown parameters of the hepatitis B virus (HBV) infection dynamics model using synthetic data.
#
# Here, the unknown parameters are estimated within a **10% variation range** around their reference values.

# %% [markdown]
# ## Cell 1: Import required libraries and setup
#
# This cell imports the required Python libraries, sets the computational device, fixes the random seeds for reproducibility, and creates the working directory for saving the generated HBV data.

# %%
# ============================================================
# Cell 1: Import required libraries and setup
# ============================================================
# This notebook estimates the unknown HBV model parameters using DINNs.
# This code is for 10% parameter variation in parameter ranges.
# The generated synthetic data are first saved and then loaded before training.

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.integrate import odeint

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# For reproducibility
np.random.seed(1234)
torch.manual_seed(1234)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Working folder for saving and loading the generated synthetic data
WORK_DIR = "HBV_DINN_10_percent_variation_in_parameter_ranges"
os.makedirs(WORK_DIR, exist_ok=True)
print("Working directory:", WORK_DIR)
# Out:
# Using device: cpu
# Working directory: HBV_DINN_10_percent_variation_in_parameter_ranges

# %% [markdown]
# ## Cell 2: Generate, save, and load simulated HBV data
#
# This cell defines the HBV infection model, solves the ODE system using the true parameter values, saves the generated synthetic data, and loads them again for DINN training.

# %%
# ============================================================
# Cell 2: Generate, save, and load simulated HBV data
# ============================================================
# The synthetic data are generated from the HBV ODE model.
# Then the data are saved as a CSV file and loaded again for DINN training.


# Initial conditions
X0 = 12.79e8
Y0 = 4.95e8
D0 = 8.04e10
V0 = 1.85e10

# Time grid
t = np.linspace(0, 500, 100)

# True parameter values
true_params = {
    "lamda": 2.6e7,
    "mu": 0.01,
    "k": 1.67e-12,
    "a": 150,
    "beta": 0.87,
    "delta": 0.053,
    "c": 3.8,
    "alpha": 0.8,
    "gamma": 0.6931
}

# HBV model
def hbv_model(y, t, lamda, mu, k, a, beta, delta, c, alpha, gamma):
    X, Y, D, V = y

    dXdt = lamda - mu * X - k * V * X
    dYdt = k * V * X - delta * Y
    dDdt = a * Y + gamma * (1 - alpha) * D - alpha * beta * D - delta * D
    dVdt = alpha * beta * D - c * V

    return [dXdt, dYdt, dDdt, dVdt]

# Initial condition vector
y0 = [X0, Y0, D0, V0]

# Solve ODE system
solution = odeint(
    hbv_model,
    y0,
    t,
    args=(
        true_params["lamda"],
        true_params["mu"],
        true_params["k"],
        true_params["a"],
        true_params["beta"],
        true_params["delta"],
        true_params["c"],
        true_params["alpha"],
        true_params["gamma"]
    )
)

# Separate simulated state variables
X, Y, D, V = solution.T

# Store data row-wise: [t, X, Y, D, V]
dataset_array = np.asarray([t, X, Y, D, V])

# Save generated synthetic data
DATA_FILE = os.path.join(WORK_DIR, "HBV_synthetic_data_10_percent.csv")
np.savetxt(DATA_FILE, dataset_array, delimiter=",")

print("Synthetic data saved at:")
print(DATA_FILE)

# Load saved synthetic data
HBV_data = np.genfromtxt(DATA_FILE, delimiter=",")

# Extract data after loading
t_data = HBV_data[0]
X_data = HBV_data[1]
Y_data = HBV_data[2]
D_data = HBV_data[3]
V_data = HBV_data[4]

print("Synthetic HBV data loaded successfully.")
print("Shape of loaded data:", HBV_data.shape)
print("Number of time points:", len(t_data))
# Out:
# Synthetic data saved at:
# HBV_DINN_10_percent_variation_in_parameter_ranges/HBV_synthetic_data_10_percent.csv
# Synthetic HBV data loaded successfully.
# Shape of loaded data: (5, 100)
# Number of time points: 100

# %% [markdown]
# ## Cell 3: Define the DINN model
#
# This cell defines the neural network architecture and the disease-informed residuals. The parameter \(\alpha\) is fixed at \(0.8\), while the remaining eight parameters are estimated.

# %%
# ============================================================
# Cell 3: Define the DINN model
# ============================================================
# alpha is fixed at 0.8 and is not estimated.
# The remaining eight parameters are estimated within 10% variation around their reference values.

class DINN(nn.Module):
    def __init__(self, t, X_data, Y_data, D_data, V_data, alpha_fixed=0.8):
        super(DINN, self).__init__()

        # Fixed alpha
        self.alpha_fixed = torch.tensor(alpha_fixed, dtype=torch.float32, device=device)

        # Time tensor with gradient
        self.t = torch.tensor(t, dtype=torch.float32, device=device).view(-1, 1)
        self.t.requires_grad_(True)

        # Data tensors
        self.X = torch.tensor(X_data, dtype=torch.float32, device=device).view(-1, 1)
        self.Y = torch.tensor(Y_data, dtype=torch.float32, device=device).view(-1, 1)
        self.D = torch.tensor(D_data, dtype=torch.float32, device=device).view(-1, 1)
        self.V = torch.tensor(V_data, dtype=torch.float32, device=device).view(-1, 1)

        # Min-max values
        self.X_min, self.X_max = torch.min(self.X), torch.max(self.X)
        self.Y_min, self.Y_max = torch.min(self.Y), torch.max(self.Y)
        self.D_min, self.D_max = torch.min(self.D), torch.max(self.D)
        self.V_min, self.V_max = torch.min(self.V), torch.max(self.V)

        # Normalized data
        self.X_hat = (self.X - self.X_min) / (self.X_max - self.X_min)
        self.Y_hat = (self.Y - self.Y_min) / (self.Y_max - self.Y_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)

        # Neural network
        self.net_HBV = self.Net_HBV().to(device)

        # Trainable transformed parameters
        self.lamda_tilda = nn.Parameter(torch.rand(1, device=device))
        self.mu_tilda = nn.Parameter(torch.rand(1, device=device))
        self.k_tilda = nn.Parameter(torch.rand(1, device=device))
        self.a_tilda = nn.Parameter(torch.rand(1, device=device))
        self.beta_tilda = nn.Parameter(torch.rand(1, device=device))
        self.delta_tilda = nn.Parameter(torch.rand(1, device=device))
        self.c_tilda = nn.Parameter(torch.rand(1, device=device))
        self.gamma_tilda = nn.Parameter(torch.rand(1, device=device))

        # History
        self.history = {
            "iteration": [],
            "total_loss": [],
            "data_loss": [],
            "residual_loss": [],
            "X_data_loss": [],
            "Y_data_loss": [],
            "D_data_loss": [],
            "V_data_loss": [],
            "f1_loss": [],
            "f2_loss": [],
            "f3_loss": [],
            "f4_loss": [],
            "lamda": [],
            "mu": [],
            "k": [],
            "a": [],
            "beta": [],
            "delta": [],
            "c": [],
            "alpha_fixed": [],
            "gamma": []
        }

        # Parameters to optimize
        self.params = list(self.net_HBV.parameters()) + [
            self.lamda_tilda,
            self.mu_tilda,
            self.k_tilda,
            self.a_tilda,
            self.beta_tilda,
            self.delta_tilda,
            self.c_tilda,
            self.gamma_tilda
        ]

    # --------------------------------------------------------
    # Parameter transformations: 10% range around references
    # p = p_ref + 0.1*p_ref*tanh(p_tilda)
    # --------------------------------------------------------

    @property
    def lamda(self):
        return torch.tanh(self.lamda_tilda) * 2.6e6 * 1 + 2.6e7

    @property
    def mu(self):
        return torch.tanh(self.mu_tilda) * 0.001 * 1 + 0.01

    @property
    def k(self):
        return torch.tanh(self.k_tilda) * 1.67e-13 * 1 + 1.67e-12

    @property
    def a(self):
        return torch.tanh(self.a_tilda) * 15 * 1 + 150

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) * 0.087 * 1 + 0.87

    @property
    def delta(self):
        return torch.tanh(self.delta_tilda) * 0.0053 * 1 + 0.053

    @property
    def c(self):
        return torch.tanh(self.c_tilda) * 0.38 * 1 + 3.8

    @property
    def alpha(self):
        return self.alpha_fixed

    @property
    def gamma(self):
        return torch.tanh(self.gamma_tilda) * 0.06931 * 1 + 0.6931

    class Net_HBV(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(1, 20)
            self.fc2 = nn.Linear(20, 20)
            self.fc3 = nn.Linear(20, 20)
            self.fc4 = nn.Linear(20, 20)
            self.out = nn.Linear(20, 4)

        def forward(self, t):
            z = F.relu(self.fc1(t))
            z = F.relu(self.fc2(z))
            z = F.relu(self.fc3(z))
            z = F.relu(self.fc4(z))
            z = self.out(z)
            return z

    def net_f(self):
        HBV_hat = self.net_HBV(self.t)

        X_hat = HBV_hat[:, 0:1]
        Y_hat = HBV_hat[:, 1:2]
        D_hat = HBV_hat[:, 2:3]
        V_hat = HBV_hat[:, 3:4]

        # Automatic differentiation
        X_hat_t = torch.autograd.grad(
            X_hat, self.t,
            grad_outputs=torch.ones_like(X_hat),
            retain_graph=True,
            create_graph=True
        )[0]

        Y_hat_t = torch.autograd.grad(
            Y_hat, self.t,
            grad_outputs=torch.ones_like(Y_hat),
            retain_graph=True,
            create_graph=True
        )[0]

        D_hat_t = torch.autograd.grad(
            D_hat, self.t,
            grad_outputs=torch.ones_like(D_hat),
            retain_graph=True,
            create_graph=True
        )[0]

        V_hat_t = torch.autograd.grad(
            V_hat, self.t,
            grad_outputs=torch.ones_like(V_hat),
            retain_graph=True,
            create_graph=True
        )[0]

        # Unnormalize predicted variables
        X = self.X_min + (self.X_max - self.X_min) * X_hat
        Y = self.Y_min + (self.Y_max - self.Y_min) * Y_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat

        # Normalized residuals
        f1_hat = X_hat_t - (
            self.lamda - self.mu * X - self.k * X * V
        ) / (self.X_max - self.X_min)

        f2_hat = Y_hat_t - (
            self.k * X * V - self.delta * Y
        ) / (self.Y_max - self.Y_min)

        f3_hat = D_hat_t - (
            self.a * Y + self.gamma * (1 - self.alpha) * D
            - self.alpha * self.beta * D - self.delta * D
        ) / (self.D_max - self.D_min)

        f4_hat = V_hat_t - (
            self.alpha * self.beta * D - self.c * V
        ) / (self.V_max - self.V_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, X_hat, Y_hat, D_hat, V_hat

    def print_loss_values(self, epoch, total_loss, data_loss, residual_loss):
        print(
            f"Epoch {epoch:7d} | "
            f"Total loss = {total_loss.item():.6e} | "
            f"Data loss = {data_loss.item():.6e} | "
            f"Residual loss = {residual_loss.item():.6e}"
        )

    def train_model(self, n_epochs, optimizer, scheduler=None, print_every=10000):
        print("Starting DINN training with fixed alpha = 0.8 ...")

        for epoch in range(n_epochs):
            optimizer.zero_grad()

            f1, f2, f3, f4, X_pred_hat, Y_pred_hat, D_pred_hat, V_pred_hat = self.net_f()

            # Data loss
            X_data_loss = torch.mean((self.X_hat - X_pred_hat) ** 2)
            Y_data_loss = torch.mean((self.Y_hat - Y_pred_hat) ** 2)
            D_data_loss = torch.mean((self.D_hat - D_pred_hat) ** 2)
            V_data_loss = torch.mean((self.V_hat - V_pred_hat) ** 2)

            data_loss = X_data_loss + Y_data_loss + D_data_loss + V_data_loss

            # Residual loss
            f1_loss = torch.mean(f1 ** 2)
            f2_loss = torch.mean(f2 ** 2)
            f3_loss = torch.mean(f3 ** 2)
            f4_loss = torch.mean(f4 ** 2)

            residual_loss = f1_loss + f2_loss + f3_loss + f4_loss

            # Total loss
            total_loss = data_loss + residual_loss

            total_loss.backward()
            optimizer.step()

            if scheduler is not None:
                scheduler.step()

            # Store history
            self.history["iteration"].append(epoch)
            self.history["total_loss"].append(total_loss.item())
            self.history["data_loss"].append(data_loss.item())
            self.history["residual_loss"].append(residual_loss.item())

            self.history["X_data_loss"].append(X_data_loss.item())
            self.history["Y_data_loss"].append(Y_data_loss.item())
            self.history["D_data_loss"].append(D_data_loss.item())
            self.history["V_data_loss"].append(V_data_loss.item())

            self.history["f1_loss"].append(f1_loss.item())
            self.history["f2_loss"].append(f2_loss.item())
            self.history["f3_loss"].append(f3_loss.item())
            self.history["f4_loss"].append(f4_loss.item())

            self.history["lamda"].append(self.lamda.item())
            self.history["mu"].append(self.mu.item())
            self.history["k"].append(self.k.item())
            self.history["a"].append(self.a.item())
            self.history["beta"].append(self.beta.item())
            self.history["delta"].append(self.delta.item())
            self.history["c"].append(self.c.item())
            self.history["alpha_fixed"].append(self.alpha.item())
            self.history["gamma"].append(self.gamma.item())

            # Print only losses every 10000 iterations and also at final iteration
            if epoch % print_every == 0 or epoch == n_epochs - 1:
                self.print_loss_values(epoch, total_loss, data_loss, residual_loss)

        print("Training completed.")

    def predict(self):
        self.eval()

        with torch.no_grad():
            HBV_hat = self.net_HBV(self.t)

            X_hat = HBV_hat[:, 0:1]
            Y_hat = HBV_hat[:, 1:2]
            D_hat = HBV_hat[:, 2:3]
            V_hat = HBV_hat[:, 3:4]

            X_pred = self.X_min + (self.X_max - self.X_min) * X_hat
            Y_pred = self.Y_min + (self.Y_max - self.Y_min) * Y_hat
            D_pred = self.D_min + (self.D_max - self.D_min) * D_hat
            V_pred = self.V_min + (self.V_max - self.V_min) * V_hat

        return (
            X_pred.cpu().numpy().flatten(),
            Y_pred.cpu().numpy().flatten(),
            D_pred.cpu().numpy().flatten(),
            V_pred.cpu().numpy().flatten()
        )

# %% [markdown]
# ## Cell 4: Initialize and train the DINN model
#
# This cell initializes the DINN model and trains it using the simulated HBV data. The total loss consists of the data loss and the residual loss obtained from the governing HBV equations.

# %%
# ============================================================
# Cell 4: Initialize and train the DINN model
# ============================================================
# Initialize DINN
dinn = DINN(
    t_data,
    X_data,
    Y_data,
    D_data,
    V_data,
    alpha_fixed=0.8
).to(device)

# Optimizer
learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr=learning_rate)

# Cyclic learning-rate scheduler
scheduler = torch.optim.lr_scheduler.CyclicLR(
    optimizer,
    base_lr=1e-6,
    max_lr=1e-3,
    step_size_up=1000,
    mode="exp_range",
    gamma=0.85,
    cycle_momentum=False
)

# Number of training epochs
N_EPOCHS = 1000000

# Train model
dinn.train_model(
    n_epochs=N_EPOCHS,
    optimizer=optimizer,
    scheduler=scheduler,
    print_every=10000
)
# Out:
# Starting DINN training with fixed alpha = 0.8 ...
# Epoch       0 | Total loss = 3.791989e+02 | Data loss = 1.451419e+01 | Residual loss = 3.646847e+02
# Epoch   10000 | Total loss = 1.041165e+00 | Data loss = 9.162576e-01 | Residual loss = 1.249078e-01
# Epoch   20000 | Total loss = 2.837569e-01 | Data loss = 2.672821e-01 | Residual loss = 1.647484e-02
# Epoch   30000 | Total loss = 2.409516e-01 | Data loss = 2.329437e-01 | Residual loss = 8.007918e-03
# Epoch   40000 | Total loss = 1.856356e-01 | Data loss = 1.845394e-01 | Residual loss = 1.096145e-03
# Epoch   50000 | Total loss = 1.486681e-01 | Data loss = 1.475984e-01 | Residual loss = 1.069723e-03
# Epoch   60000 | Total loss = 1.248656e-01 | Data loss = 1.234613e-01 | Residual loss = 1.404328e-03
# Epoch   70000 | Total loss = 1.073768e-01 | Data loss = 1.043451e-01 | Residual loss = 3.031750e-03
# Epoch   80000 | Total loss = 9.270956e-02 | Data loss = 9.073672e-02 | Residual loss = 1.972845e-03
# Epoch   90000 | Total loss = 8.162629e-02 | Data loss = 7.985367e-02 | Residual loss = 1.772618e-03
# Epoch  100000 | Total loss = 6.740051e-02 | Data loss = 6.520505e-02 | Residual loss = 2.195457e-03
# Epoch  110000 | Total loss = 5.406421e-02 | Data loss = 5.075925e-02 | Residual loss = 3.304962e-03
# Epoch  120000 | Total loss = 4.231760e-02 | Data loss = 4.036989e-02 | Residual loss = 1.947704e-03
# Epoch  130000 | Total loss = 3.366785e-02 | Data loss = 3.231596e-02 | Residual loss = 1.351893e-03
# Epoch  140000 | Total loss = 2.702326e-02 | Data loss = 2.629210e-02 | Residual loss = 7.311628e-04
# Epoch  150000 | Total loss = 2.213373e-02 | Data loss = 2.155109e-02 | Residual loss = 5.826385e-04
# Epoch  160000 | Total loss = 1.776630e-02 | Data loss = 1.726449e-02 | Residual loss = 5.018122e-04
# Epoch  170000 | Total loss = 1.301603e-02 | Data loss = 1.239998e-02 | Residual loss = 6.160417e-04
# Epoch  180000 | Total loss = 8.319003e-03 | Data loss = 7.809051e-03 | Residual loss = 5.099511e-04
# Epoch  190000 | Total loss = 5.113799e-03 | Data loss = 4.796222e-03 | Residual loss = 3.175769e-04
# Epoch  200000 | Total loss = 3.640675e-03 | Data loss = 3.329404e-03 | Residual loss = 3.112706e-04
# Epoch  210000 | Total loss = 2.837783e-03 | Data loss = 2.609269e-03 | Residual loss = 2.285148e-04
# Epoch  220000 | Total loss = 2.267861e-03 | Data loss = 2.060809e-03 | Residual loss = 2.070521e-04
# Epoch  230000 | Total loss = 1.822076e-03 | Data loss = 1.672678e-03 | Residual loss = 1.493985e-04
# Epoch  240000 | Total loss = 1.593475e-03 | Data loss = 1.456219e-03 | Residual loss = 1.372560e-04
# Epoch  250000 | Total loss = 1.428645e-03 | Data loss = 1.279563e-03 | Residual loss = 1.490811e-04
# Epoch  260000 | Total loss = 1.234282e-03 | Data loss = 1.098543e-03 | Residual loss = 1.357396e-04
# Epoch  270000 | Total loss = 1.072478e-03 | Data loss = 9.544191e-04 | Residual loss = 1.180591e-04
# Epoch  280000 | Total loss = 9.191212e-04 | Data loss = 8.179111e-04 | Residual loss = 1.012101e-04
# Epoch  290000 | Total loss = 7.859262e-04 | Data loss = 6.998160e-04 | Residual loss = 8.611017e-05
# Epoch  300000 | Total loss = 6.903253e-04 | Data loss = 6.180293e-04 | Residual loss = 7.229592e-05
# Epoch  310000 | Total loss = 6.023107e-04 | Data loss = 5.419117e-04 | Residual loss = 6.039899e-05
# Epoch  320000 | Total loss = 5.286296e-04 | Data loss = 4.813932e-04 | Residual loss = 4.723637e-05
# Epoch  330000 | Total loss = 4.768772e-04 | Data loss = 4.387368e-04 | Residual loss = 3.814034e-05
# Epoch  340000 | Total loss = 4.423321e-04 | Data loss = 4.082517e-04 | Residual loss = 3.408043e-05
# Epoch  350000 | Total loss = 4.182154e-04 | Data loss = 3.871706e-04 | Residual loss = 3.104476e-05
# Epoch  360000 | Total loss = 3.982026e-04 | Data loss = 3.705984e-04 | Residual loss = 2.760427e-05
# Epoch  370000 | Total loss = 3.864088e-04 | Data loss = 3.583762e-04 | Residual loss = 2.803263e-05
# Epoch  380000 | Total loss = 3.717645e-04 | Data loss = 3.423822e-04 | Residual loss = 2.938237e-05
# Epoch  390000 | Total loss = 3.535327e-04 | Data loss = 3.306920e-04 | Residual loss = 2.284064e-05
# Epoch  400000 | Total loss = 3.365716e-04 | Data loss = 3.144084e-04 | Residual loss = 2.216325e-05
# Epoch  410000 | Total loss = 3.112431e-04 | Data loss = 2.910970e-04 | Residual loss = 2.014605e-05
# Epoch  420000 | Total loss = 2.864558e-04 | Data loss = 2.674559e-04 | Residual loss = 1.899993e-05
# Epoch  430000 | Total loss = 2.650005e-04 | Data loss = 2.460902e-04 | Residual loss = 1.891029e-05
# Epoch  440000 | Total loss = 2.421451e-04 | Data loss = 2.243963e-04 | Residual loss = 1.774887e-05
# Epoch  450000 | Total loss = 2.196725e-04 | Data loss = 2.034250e-04 | Residual loss = 1.624750e-05
# Epoch  460000 | Total loss = 1.990126e-04 | Data loss = 1.830902e-04 | Residual loss = 1.592243e-05
# Epoch  470000 | Total loss = 2.040217e-04 | Data loss = 1.674396e-04 | Residual loss = 3.658204e-05
# Epoch  480000 | Total loss = 1.594870e-04 | Data loss = 1.453643e-04 | Residual loss = 1.412265e-05
# Epoch  490000 | Total loss = 1.591144e-04 | Data loss = 1.347140e-04 | Residual loss = 2.440038e-05
# Epoch  500000 | Total loss = 1.331818e-04 | Data loss = 1.203915e-04 | Residual loss = 1.279023e-05
# Epoch  510000 | Total loss = 1.197182e-04 | Data loss = 1.081741e-04 | Residual loss = 1.154417e-05
# Epoch  520000 | Total loss = 1.097635e-04 | Data loss = 9.906941e-05 | Residual loss = 1.069409e-05
# Epoch  530000 | Total loss = 1.033646e-04 | Data loss = 9.342276e-05 | Residual loss = 9.941868e-06
# Epoch  540000 | Total loss = 1.479251e-04 | Data loss = 1.281807e-04 | Residual loss = 1.974438e-05
# Epoch  550000 | Total loss = 1.230881e-04 | Data loss = 1.131135e-04 | Residual loss = 9.974586e-06
# Epoch  560000 | Total loss = 1.143042e-04 | Data loss = 1.046177e-04 | Residual loss = 9.686434e-06
# Epoch  570000 | Total loss = 1.028027e-04 | Data loss = 9.411753e-05 | Residual loss = 8.685127e-06
# Epoch  580000 | Total loss = 9.547776e-05 | Data loss = 8.728103e-05 | Residual loss = 8.196731e-06
# Epoch  590000 | Total loss = 9.161104e-05 | Data loss = 8.383283e-05 | Residual loss = 7.778217e-06
# Epoch  600000 | Total loss = 8.984718e-05 | Data loss = 8.244765e-05 | Residual loss = 7.399526e-06
# Epoch  610000 | Total loss = 8.888891e-05 | Data loss = 8.185765e-05 | Residual loss = 7.031258e-06
# Epoch  620000 | Total loss = 8.816110e-05 | Data loss = 8.138595e-05 | Residual loss = 6.775149e-06
# Epoch  630000 | Total loss = 8.756614e-05 | Data loss = 8.104578e-05 | Residual loss = 6.520355e-06
# Epoch  640000 | Total loss = 9.210892e-05 | Data loss = 8.068619e-05 | Residual loss = 1.142274e-05
# Epoch  650000 | Total loss = 8.664351e-05 | Data loss = 8.042883e-05 | Residual loss = 6.214684e-06
# Epoch  660000 | Total loss = 8.627320e-05 | Data loss = 8.015744e-05 | Residual loss = 6.115771e-06
# Epoch  670000 | Total loss = 8.612810e-05 | Data loss = 7.990844e-05 | Residual loss = 6.219653e-06
# Epoch  680000 | Total loss = 8.580545e-05 | Data loss = 7.975276e-05 | Residual loss = 6.052688e-06
# Epoch  690000 | Total loss = 8.545951e-05 | Data loss = 7.950402e-05 | Residual loss = 5.955496e-06
# Epoch  700000 | Total loss = 8.516368e-05 | Data loss = 7.928356e-05 | Residual loss = 5.880115e-06
# Epoch  710000 | Total loss = 8.494924e-05 | Data loss = 7.911391e-05 | Residual loss = 5.835334e-06
# Epoch  720000 | Total loss = 8.471218e-05 | Data loss = 7.892578e-05 | Residual loss = 5.786399e-06
# Epoch  730000 | Total loss = 8.460038e-05 | Data loss = 7.884191e-05 | Residual loss = 5.758468e-06
# Epoch  740000 | Total loss = 8.426783e-05 | Data loss = 7.862477e-05 | Residual loss = 5.643056e-06
# Epoch  750000 | Total loss = 8.742898e-05 | Data loss = 7.838961e-05 | Residual loss = 9.039365e-06
# Epoch  760000 | Total loss = 8.382542e-05 | Data loss = 7.827368e-05 | Residual loss = 5.551748e-06
# Epoch  770000 | Total loss = 8.669815e-05 | Data loss = 7.808051e-05 | Residual loss = 8.617636e-06
# Epoch  780000 | Total loss = 8.345121e-05 | Data loss = 7.795094e-05 | Residual loss = 5.500273e-06
# Epoch  790000 | Total loss = 8.330846e-05 | Data loss = 7.784826e-05 | Residual loss = 5.460207e-06
# Epoch  800000 | Total loss = 8.312954e-05 | Data loss = 7.770650e-05 | Residual loss = 5.423039e-06
# Epoch  810000 | Total loss = 8.297552e-05 | Data loss = 7.756674e-05 | Residual loss = 5.408779e-06
# Epoch  820000 | Total loss = 8.283908e-05 | Data loss = 7.747265e-05 | Residual loss = 5.366427e-06
# Epoch  830000 | Total loss = 8.270266e-05 | Data loss = 7.736373e-05 | Residual loss = 5.338928e-06
# Epoch  840000 | Total loss = 8.256300e-05 | Data loss = 7.723635e-05 | Residual loss = 5.326647e-06
# Epoch  850000 | Total loss = 8.243188e-05 | Data loss = 7.712601e-05 | Residual loss = 5.305871e-06
# Epoch  860000 | Total loss = 8.232975e-05 | Data loss = 7.706914e-05 | Residual loss = 5.260615e-06
# Epoch  870000 | Total loss = 8.221391e-05 | Data loss = 7.690762e-05 | Residual loss = 5.306289e-06
# Epoch  880000 | Total loss = 8.212859e-05 | Data loss = 7.681078e-05 | Residual loss = 5.317817e-06
# Epoch  890000 | Total loss = 8.196358e-05 | Data loss = 7.674347e-05 | Residual loss = 5.220103e-06
# Epoch  900000 | Total loss = 8.187260e-05 | Data loss = 7.664422e-05 | Residual loss = 5.228382e-06
# Epoch  910000 | Total loss = 8.176331e-05 | Data loss = 7.655341e-05 | Residual loss = 5.209906e-06
# Epoch  920000 | Total loss = 8.162520e-05 | Data loss = 7.647439e-05 | Residual loss = 5.150810e-06
# Epoch  930000 | Total loss = 8.160610e-05 | Data loss = 7.637235e-05 | Residual loss = 5.233748e-06
# Epoch  940000 | Total loss = 8.277374e-05 | Data loss = 7.628604e-05 | Residual loss = 6.487700e-06
# Epoch  950000 | Total loss = 8.133705e-05 | Data loss = 7.623334e-05 | Residual loss = 5.103715e-06
# Epoch  960000 | Total loss = 8.257301e-05 | Data loss = 7.614966e-05 | Residual loss = 6.423347e-06
# Epoch  970000 | Total loss = 8.118844e-05 | Data loss = 7.609995e-05 | Residual loss = 5.088495e-06
# Epoch  980000 | Total loss = 8.230402e-05 | Data loss = 7.600022e-05 | Residual loss = 6.303795e-06
# Epoch  990000 | Total loss = 8.104067e-05 | Data loss = 7.594922e-05 | Residual loss = 5.091447e-06
# Epoch  999999 | Total loss = 8.088961e-05 | Data loss = 7.586191e-05 | Residual loss = 5.027698e-06
# Training completed.

# %% [markdown]
# ## Cell 5: Print the final estimated parameter values
#
# After training, this cell prints the estimated values of the unknown parameters and compares them with the corresponding true values. The fixed parameter \(\alpha\) is also reported separately.

# %%
# ============================================================
# Cell 5: Print final estimated parameter values
# ============================================================
# alpha is fixed at 0.8.
# The remaining eight parameters are estimated.

final_params_df = pd.DataFrame({
    "parameter": [
        "lamda", "mu", "k", "a", "beta", "delta", "c", "alpha", "gamma"
    ],
    "true_value": [
        true_params["lamda"],
        true_params["mu"],
        true_params["k"],
        true_params["a"],
        true_params["beta"],
        true_params["delta"],
        true_params["c"],
        true_params["alpha"],
        true_params["gamma"]
    ],
    "estimated_or_fixed_value": [
        dinn.lamda.item(),
        dinn.mu.item(),
        dinn.k.item(),
        dinn.a.item(),
        dinn.beta.item(),
        dinn.delta.item(),
        dinn.c.item(),
        dinn.alpha.item(),
        dinn.gamma.item()
    ],
    "status": [
        "estimated",
        "estimated",
        "estimated",
        "estimated",
        "estimated",
        "estimated",
        "estimated",
        "fixed",
        "estimated"
    ]
})

print("Final estimated parameter values:")
print(final_params_df)
# Out:
# Final estimated parameter values:
#   parameter    true_value  estimated_or_fixed_value     status
# 0     lamda  2.600000e+07              2.689926e+07  estimated
# 1        mu  1.000000e-02              1.021772e-02  estimated
# 2         k  1.670000e-12              1.733427e-12  estimated
# 3         a  1.500000e+02              1.548883e+02  estimated
# 4      beta  8.700000e-01              9.050047e-01  estimated
# 5     delta  5.300000e-02              5.497276e-02  estimated
# 6         c  3.800000e+00              3.952638e+00  estimated
# 7     alpha  8.000000e-01              8.000000e-01      fixed
# 8     gamma  6.931000e-01              7.440035e-01  estimated

# %% [markdown]
# ## Cell 6: Generate DINN predictions
#
# This cell uses the trained DINN model to predict the HBV state variables over the full time interval.

# %%
# ============================================================
# Cell 6: Generate predictions


X_pred, Y_pred, D_pred, V_pred = dinn.predict()

print("Predictions generated successfully.")
# Out:
# Predictions generated successfully.

# %% [markdown]
# ## Cell 7: Plot true data and DINN predictions
#
# This cell plots the true simulated data and the DINN-predicted trajectories for all four state variables: \(X\), \(Y\), \(D\), and \(V\).

# %%
# ============================================================
# Cell 7: Plot true data and DINN predictions
# ============================================================

fig, axs = plt.subplots(1, 4, figsize=(28, 7))
fig.patch.set_facecolor("white")

ax1, ax2, ax3, ax4 = axs.flatten()

# X
ax1.scatter(t_data, X_data, color="red", alpha=0.9, label="Uninfected data", s=45)
ax1.plot(t_data, X_pred, color="blue", lw=4, label="Uninfected prediction")
ax1.set_title("Uninfected hepatocytes", fontsize=26)
ax1.set_xlabel("Time (days)", fontsize=28)
ax1.set_ylabel(r"Concentration of $X$", fontsize=28)
ax1.legend(fontsize=18)
ax1.tick_params(axis="both", labelsize=20)
ax1.yaxis.get_offset_text().set_fontsize(20)

# Y
ax2.scatter(t_data, Y_data, color="red", alpha=0.9, label="Infected data", s=45)
ax2.plot(t_data, Y_pred, color="blue", lw=4, label="Infected prediction")
ax2.set_title("Infected hepatocytes", fontsize=26)
ax2.set_xlabel("Time (days)", fontsize=28)
ax2.set_ylabel(r"Concentration of $Y$", fontsize=28)
ax2.legend(fontsize=18)
ax2.tick_params(axis="both", labelsize=20)
ax2.yaxis.get_offset_text().set_fontsize(20)

# D
ax3.scatter(t_data, D_data, color="red", alpha=0.9, label="Capsid data", s=45)
ax3.plot(t_data, D_pred, color="blue", lw=4, label="Capsid prediction")
ax3.set_title("Capsids", fontsize=26)
ax3.set_xlabel("Time (days)", fontsize=28)
ax3.set_ylabel(r"Concentration of $D$", fontsize=28)
ax3.legend(fontsize=18)
ax3.tick_params(axis="both", labelsize=20)
ax3.yaxis.get_offset_text().set_fontsize(20)

# V
ax4.scatter(t_data, V_data, color="red", alpha=0.9, label="Virion data", s=45)
ax4.plot(t_data, V_pred, color="blue", lw=4, label="Virion prediction")
ax4.set_title("Virions", fontsize=26)
ax4.set_xlabel("Time (days)", fontsize=28)
ax4.set_ylabel(r"Concentration of $V$", fontsize=28)
ax4.legend(fontsize=18)
ax4.tick_params(axis="both", labelsize=20)
ax4.yaxis.get_offset_text().set_fontsize(20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cell 8: Calculate and print RRMSE errors
#
# This cell computes the relative root mean square error (RRMSE) between the true data and the DINN predictions for each state variable.

# %%
# ============================================================
# Cell 8: Calculate and print RRMSE errors
# ============================================================
# RRMSE = sqrt(sum((true - predicted)^2) / sum(true^2))


def rrmse_error(true, pred):
    return np.sqrt(np.sum((true - pred) ** 2) / np.sum(true ** 2))

X_RRMSE = rrmse_error(X_data, X_pred)
Y_RRMSE = rrmse_error(Y_data, Y_pred)
D_RRMSE = rrmse_error(D_data, D_pred)
V_RRMSE = rrmse_error(V_data, V_pred)

rrmse_df = pd.DataFrame({
    "variable": ["X", "Y", "D", "V"],
    "RRMSE_error": [
        X_RRMSE,
        Y_RRMSE,
        D_RRMSE,
        V_RRMSE
    ]
})

print("RRMSE errors:")
print(rrmse_df)
# Out:
# RRMSE errors:
#   variable  RRMSE_error
# 0        X     0.004031
# 1        Y     0.004372
# 2        D     0.004306
# 3        V     0.004341
